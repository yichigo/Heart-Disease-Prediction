# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
import sklearn.tree as tree
from sklearn.metrics import plot_confusion_matrix

# Classifiers 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

dir_out = '../plots/'

# %%
dir_in = '../data/emg-4/'

col_names = []
for i in range(8):
    for j in range(8):
        col_names.append('muscle reading '+ str(i+1)+' sensor '+str(j+1))
col_names.append('gestures')

# Gesture classes were : rock - 0, scissors - 1, paper - 2, ok - 3

df = []        
for i in range(4):
    fn = dir_in + str(i) + '.csv'
    df_i = pd.read_csv(fn, header=None,index_col = False, names = col_names)
    print(len(df_i))
    if len(df) == 0:
        df = df_i
    else:
        df = df.append(df_i)
display(df.head())

print(len(df))
# Out:
# 2910
# 2903
# 2943
# 2922
#    muscle reading 1 sensor 1  muscle reading 1 sensor 2  \
# 0                       26.0                        4.0
# 1                      -47.0                       -6.0
# 2                      -19.0                       -8.0
# 3                        2.0                        3.0
# 4                        6.0                        0.0
#
#    muscle reading 1 sensor 3  muscle reading 1 sensor 4  \
# 0                        5.0                        8.0
# 1                       -5.0                       -7.0
# 2                       -8.0                       -8.0
# 3                        0.0                        2.0
# 4                        0.0                       -2.0
#
#    muscle reading 1 sensor 5  muscle reading 1 sensor 6  \
# 0                       -1.0                      -13.0
# 1                       13.0                       -1.0
# 2                      -21.0                       -6.0
# 3                        0.0                       22.0
# 4                      -14.0                       10.0
#
#    muscle reading 1 sensor 7  muscle reading 1 sensor 8  \
# 0                     -109.0                      -66.0
# 1                       35.0                      -10.0
# 2                      -79.0                       12.0
# 3                      106.0                      -14.0
# 4                      -51.0                        5.0
#
#    muscle reading 2 sensor 1  muscle reading 2 sensor 2  ...  \
# 0                       -9.0                        2.0  ...
# 1                       10.0                       -4.0  ...
# 2                        0.0                        5.0  ...
# 3                      -16.0                       -2.0  ...
# 4                        7.0                        0.0  ...
#
#    muscle reading 7 sensor 8  muscle reading 8 sensor 1  \
# 0                      -28.0                       61.0
# 1                      -25.0                       47.0
# 2                      -83.0                        7.0
# 3                      -38.0                      -11.0
# 4                       38.0                      -35.0
#
#    muscle reading 8 sensor 2  muscle reading 8 sensor 3  \
# 0                        4.0                        8.0
# 1                        6.0                        6.0
# 2                        7.0                        1.0
# 3                        4.0                        7.0
# 4                       -8.0                        2.0
#
#    muscle reading 8 sensor 4  muscle reading 8 sensor 5  \
# 0                        5.0                        4.0
# 1                        5.0                       13.0
# 2                       -8.0                        7.0
# 3                       11.0                       33.0
# 4                        6.0                      -13.0
#
#    muscle reading 8 sensor 6  muscle reading 8 sensor 7  \
# 0                       -7.0                      -59.0
# 1                       21.0                      111.0
# 2                       21.0                      114.0
# 3                       39.0                      119.0
# 4                      -24.0                     -112.0
#
#    muscle reading 8 sensor 8  gestures
# 0                       16.0         0
# 1                       15.0         0
# 2                       48.0         0
# 3                       43.0         0
# 4                      -69.0         0
#
# [5 rows x 65 columns]
# 11678

# %%
RANDOM_STATE_DATA = 0
X = df.drop(['gestures'],axis=1)
y = df['gestures']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE_DATA)

# %%
# DecisionTreeClassifier, grid search to find best parameter
RANDOM_STATE = 42
clf = DecisionTreeClassifier(random_state=RANDOM_STATE, criterion='gini')
param_grid = {'max_depth': [10,20,50,100]}
CV_clf = GridSearchCV(estimator = clf, param_grid = param_grid, cv =5, verbose = 3)

CV_clf.fit(X_train, y_train)
print(CV_clf.best_params_)
print(CV_clf.best_score_)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] max_depth=10 ....................................................
# [CV] ........................ max_depth=10, score=0.762, total=   0.2s
# [CV] max_depth=10 ....................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ........................ max_depth=10, score=0.758, total=   0.2s
# [CV] max_depth=10 ....................................................
# [CV] ........................ max_depth=10, score=0.755, total=   0.2s
# [CV] max_depth=10 ....................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] ........................ max_depth=10, score=0.762, total=   0.2s
# [CV] max_depth=10 ....................................................
# [CV] ........................ max_depth=10, score=0.755, total=   0.2s
# [CV] max_depth=20 ....................................................
# [CV] ........................ max_depth=20, score=0.791, total=   0.3s
# [CV] max_depth=20 ....................................................
# [CV] ........................ max_depth=20, score=0.777, total=   0.3s
# [CV] max_depth=20 ....................................................
# [CV] ........................ max_depth=20, score=0.783, total=   0.3s
# [CV] max_depth=20 ....................................................
# [CV] ........................ max_depth=20, score=0.786, total=   0.3s
# [CV] max_depth=20 ....................................................
# [CV] ........................ max_depth=20, score=0.786, total=   0.3s
# [CV] max_depth=50 ....................................................
# [CV] ........................ max_depth=50, score=0.781, total=   0.4s
# [CV] max_depth=50 ....................................................
# [CV] ........................ max_depth=50, score=0.758, total=   0.4s
# [CV] max_depth=50 ....................................................
# [CV] ........................ max_depth=50, score=0.763, total=   0.4s
# [CV] max_depth=50 ....................................................
# [CV] ........................ max_depth=50, score=0.776, total=   0.4s
# [CV] max_depth=50 ....................................................
# [CV] ........................ max_depth=50, score=0.780, total=   0.5s
# [CV] max_depth=100 ...................................................
# [CV] ....................... max_depth=100, score=0.787, total=   0.4s
# [CV] max_depth=100 ...................................................
# [CV] ....................... max_depth=100, score=0.744, total=   0.5s
# [CV] max_depth=100 ...................................................
# [CV] ....................... max_depth=100, score=0.763, total=   0.4s
# [CV] max_depth=100 ...................................................
# [CV] ....................... max_depth=100, score=0.776, total=   0.4s
# [CV] max_depth=100 ...................................................
# [CV] ....................... max_depth=100, score=0.779, total=   0.4s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    6.7s finished
# {'max_depth': 20}
# 0.784842745894643

# %%
RANDOM_STATE_MODEL = 42
clf = DecisionTreeClassifier(random_state = RANDOM_STATE_MODEL,
                             criterion='gini',
                             max_depth=20#CV_clf.best_params_['max_depth']
                            )
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=20, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
labels = [0,1,2,3]
label_names = ['rock-0', 'scissors-1', 'paper-2', 'ok-3']

plt.rcParams["figure.figsize"] = (8, 8)

plot_confusion_matrix(clf, X_train, y_train,labels = labels, display_labels = label_names, xticks_rotation = 45, cmap=plt.cm.Blues)
plt.title('Confusion Matrix:\n Decision Tree (Train)', fontsize = 20)
plt.tight_layout()
plt.savefig(dir_out +'CM_DT_train.png')
plt.close()

plot_confusion_matrix(clf, X_test, y_test,labels = labels, display_labels = label_names, xticks_rotation = 45, cmap=plt.cm.Blues)
plt.title('Confusion Matrix:\n Decision Tree (Test)', fontsize = 20)
plt.tight_layout()
plt.savefig(dir_out +'CM_DT_test.png')
plt.close()

# %%
from plot_learning_curve import plot_learning_curve
from sklearn.model_selection import ShuffleSplit

# %%
title =  'Learning Curve of Decision Tree'
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

plot_learning_curve(clf, title, X, y, ylim=(0.5, 1.01),
                    cv=cv, n_jobs=4)#, train_sizes = np.linspace(0.1, 1.0, 10))
plt.savefig(dir_out +'LC_DT.png')
plt.close()
